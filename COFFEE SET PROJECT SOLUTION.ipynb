# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('coffee.xlsx')
df.head()
# Out:
#    Area Code   Date   Market   Market Size            Product Product Line  \
# 0        719  40909  Central  Major Market           Amaretto        Beans
# 1        970  40909  Central  Major Market          Colombian        Beans
# 2        970  40909  Central  Major Market  Decaf Irish Cream        Beans
# 3        303  40909  Central  Major Market          Green Tea       Leaves
# 4        303  40909  Central  Major Market        Caffe Mocha        Beans
#
#   Product Type     State     Type  Budget COGS  Budget Margin  Budget Profit  \
# 0       Coffee  Colorado  Regular           90            130            100
# 1       Coffee  Colorado  Regular           80            110             80
# 2       Coffee  Colorado    Decaf          100            140            110
# 3          Tea  Colorado  Regular           30             50             30
# 4     Espresso  Colorado  Regular           60             90             70
#
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Date', 'Market', 'Market Size', 'Product', 'Product Line',
#        'Product Type', 'State', 'Type', 'Budget COGS', 'Budget Margin',
#        'Budget Profit', 'Budget Sales', 'COGS', 'Inventory', 'Margin',
#        'Marketing', 'Profit', 'Sales', 'Total Expenses'],
#       dtype='object')

# %%
df.shape
# Out:
# (4248, 20)

# %%
df.isnull().sum()
# Out:
# Area Code         0
# Date              0
# Market            0
# Market Size       0
# Product           0
# Product Line      0
# Product Type      0
# State             0
# Type              0
# Budget COGS       0
# Budget Margin     0
# Budget Profit     0
# Budget Sales      0
# COGS              0
# Inventory         0
# Margin            0
# Marketing         0
# Profit            0
# Sales             0
# Total Expenses    0
# dtype: int64

# %%
df.dtypes
# Out:
# Area Code          int64
# Date               int64
# Market            object
# Market Size       object
# Product           object
# Product Line      object
# Product Type      object
# State             object
# Type              object
# Budget COGS        int64
# Budget Margin      int64
# Budget Profit      int64
# Budget Sales       int64
# COGS               int64
# Inventory          int64
# Margin             int64
# Marketing          int64
# Profit             int64
# Sales              int64
# Total Expenses     int64
# dtype: object

# %%
d1=df['Market'].value_counts()
d1
# Out:
# Central    1344
# West       1344
# East        888
# South       672
# Name: Market, dtype: int64

# %%
plt.bar(d1.index,d1,label='Market type',color='orange')
plt.legend()
plt.xlabel('Market type')
plt.ylabel('Count')
plt.xticks(rotation=50)
plt.show()

# %%
d2=df['Product Type'].value_counts()
d2
# Out:
# Espresso      1176
# Herbal Tea    1056
# Coffee        1056
# Tea            960
# Name: Product Type, dtype: int64

# %%
plt.plot(d2.index,d2,label='Product Type',color='blue')
plt.legend()
plt.xlabel('Product Type')
plt.ylabel('count')
plt.xticks(rotation=50)
plt.show()

# %%
d3=df['State'].value_counts()
d3
# Out:
# Utah             288
# California       288
# Nevada           264
# Oregon           264
# Colorado         264
# Washington       240
# Wisconsin        216
# Iowa             216
# Florida          216
# Missouri         216
# Illinois         216
# Ohio             216
# New York         192
# New Hampshire    168
# Connecticut      168
# New Mexico       168
# Oklahoma         168
# Louisiana        168
# Texas            168
# Massachusetts    144
# Name: State, dtype: int64

# %%
plt.pie(x=d3,labels=d3.index,autopct="%.2f%%")
plt.legend(loc=2)
plt.title('state distribution')
plt.show()

# %%
df['Profit'].unique()
# Out:
# array([  94,   68,  101,   30,   54,   53,   99,    0,   33,   17,   36,
#         111,   87,  203,  140,   95,   11,    5,   12,   10,  202,   86,
#         141,  175,   39,   47,   -4,   48,   45,  -11,  -39,    9,   -9,
#          34,   42,   67,   16,   29,   13,   51,    7,   38,   70,   28,
#          35,  115,   40,   50,  100,  -23,  367,   -8,  -10,   20,   25,
#        -172,  262, -113,    8,    4,   26,   66,  159,   44,   21,  -40,
#         102,  160,   -2, -117, -354,   -3,    1,  105,   80,   59,   18,
#         201,  142,   79,    6,   32,  169,   46,  -32,   -7,   62,   71,
#          98,   15,   41,    3,   43,  121,   63,  340,   -6,   23,  264,
#        -203,  245,  131, -120,   65,    2,   24,  -31,   58,  106,  164,
#         -27,   31, -342,   -5,   90,   69,   84,  119,  211,  148,   91,
#         212,   74,   55,  114,   27,  366,   83, -208,  194,  259, -119,
#         -33,  166,  149, -121,  165,  -41, -340,   96,  156,   49,  220,
# ...

# %%
d4=df["Market"].value_counts()
d4
# Out:
# Central    1344
# West       1344
# East        888
# South       672
# Name: Market, dtype: int64

# %%
df1=df.groupby('Market')['Profit'].sum()
df1
# Out:
# Market
# Central    93852
# East       59217
# South      32478
# West       73996
# Name: Profit, dtype: int64

# %%
plt.bar(df1.index,df1,color='green')
plt.show()

# %%
df['Sales'].unique()
# Out:
# array([219, 190, 234, 100, 134, 180, 341, 150, 140, 130, 345, 546, 456,
#         45,  62,  54,  43, 170,  76, 123, 114,  90,  99,  82,  65, 200,
#         80, 210, 120, 110,  81,  94, 310, 126, 494,  93, 490,  61, 678,
#        483, 112,  85, 452, 250, 145, 118,  17, 160, 243, 232, 189, 340,
#        129, 132, 136, 354, 254, 545, 457,  63,  47, 534, 193, 165,  74,
#        103, 104, 102,  68, 128, 206,  56, 220, 137, 155, 154, 174, 115,
#         66, 325, 470, 101, 580, 645, 495, 465, 290, 122,  23, 142, 213,
#         98, 198, 125, 135, 367, 267, 567, 478,  41, 163,  75, 121, 107,
#        106, 214,  53,  79, 227, 188, 167, 124, 309, 492, 119, 523, 675,
#        513, 182, 467, 298, 127,  32,  92, 149, 223, 178, 138, 245, 587,
#        301, 578,  49,  88, 133, 222, 151, 195, 292, 117, 519, 564, 712,
#        638,  86, 159,  26,  87, 169, 256, 612, 521, 312, 589,  52, 109,
#         97, 173, 148, 235, 273,  71, 221, 204,  57, 113, 275,  89, 551,
# ...

# %%
d5=df["Product"].value_counts()
d5
# Out:
# Colombian            480
# Lemon                480
# Caffe Mocha          480
# Decaf Espresso       408
# Chamomile            384
# Darjeeling           384
# Decaf Irish Cream    384
# Earl Grey            288
# Green Tea            288
# Caffe Latte          216
# Mint                 192
# Amaretto             192
# Regular Espresso      72
# Name: Product, dtype: int64

# %%
df2=df.groupby('Product')['Sales'].mean()
df2
# Out:
# Product
# Amaretto             136.817708
# Caffe Latte          166.199074
# Caffe Mocha          176.883333
# Chamomile            196.817708
# Colombian            267.314583
# Darjeeling           190.497396
# Decaf Espresso       191.573529
# Decaf Irish Cream    162.104167
# Earl Grey            231.847222
# Green Tea            114.062500
# Lemon                199.845833
# Mint                 185.989583
# Regular Espresso     333.763889
# Name: Sales, dtype: float64

# %%
plt.bar(df2.index,df2,color="yellow")
plt.xticks(rotation=50)
plt.grid()
plt.show()

# %%
d6=df[df['Product']=='Regular Espresso']
d6
# Out:
#       Area Code   Date Market   Market Size           Product Product Line  \
# 74          978  40909   East  Major Market  Regular Espresso        Beans
# 80          603  40909   East  Small Market  Regular Espresso        Beans
# 88          631  40909   East  Major Market  Regular Espresso        Beans
# 251         508  40940   East  Major Market  Regular Espresso        Beans
# 257         603  40940   East  Small Market  Regular Espresso        Beans
# ...         ...    ...    ...           ...               ...          ...
# 3976        603  41579   East  Small Market  Regular Espresso        Beans
# 3985        917  41579   East  Major Market  Regular Espresso        Beans
# 4147        857  41609   East  Major Market  Regular Espresso        Beans
# 4153        603  41609   East  Small Market  Regular Espresso        Beans
# 4162        518  41609   East  Major Market  Regular Espresso        Beans
#
# ...

# %%
plt.scatter(d6['Profit'],d6['Sales'],marker='*')
plt.title('Sales vs Profit for product Regular Espresso')
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.show()

# %%
d7 = df[(df['Product']=='Earl Grey') & (df['State']=='California')]
d7
# Out:
#       Area Code   Date Market   Market Size    Product Product Line  \
# 140         650  40909   West  Major Market  Earl Grey       Leaves
# 317         858  40940   West  Major Market  Earl Grey       Leaves
# 495         951  40969   West  Major Market  Earl Grey       Leaves
# 674         530  41000   West  Major Market  Earl Grey       Leaves
# 851         530  41030   West  Major Market  Earl Grey       Leaves
# 1027        415  41061   West  Major Market  Earl Grey       Leaves
# 1201        831  41091   West  Major Market  Earl Grey       Leaves
# 1378        310  41122   West  Major Market  Earl Grey       Leaves
# 1555        714  41153   West  Major Market  Earl Grey       Leaves
# 1730        209  41183   West  Major Market  Earl Grey       Leaves
# 1907        650  41214   West  Major Market  Earl Grey       Leaves
# 2084        619  41244   West  Major Market  Earl Grey       Leaves
# 2261        707  41275   West  Major Market  Earl Grey       Leaves
# ...

# %%
plt.scatter(d7['Budget Profit'],d7['Budget Sales'],marker='*')
plt.title('Budget Sales vs Budget Profit for product Earl grey')
plt.xlabel('Budget Profit')
plt.ylabel('Budget Sales')
plt.show()

# %%
df3=df.groupby('Market')['Budget Sales'].mean()
df3
# Out:
# Market
# Central    186.279762
# East       177.815315
# South      146.130952
# West       178.348214
# Name: Budget Sales, dtype: float64

# %%
df4=df.groupby('Market')['Sales'].mean()
df4
# Out:
# Market
# Central    197.206101
# East       201.099099
# South      154.651786
# West       202.577381
# Name: Sales, dtype: float64

# %%
plt.bar(df3,df4,color="green")
plt.title('Market wise mean of budget sales vs market wise mean of sales')
plt.xlabel('Market wise budget sales')
plt.ylabel('Market wise sales')
plt.xticks(rotation=50)
plt.grid()
plt.show()

# %%
d8=df['Total Expenses'].value_counts()
d8
# Out:
# 45     140
# 46     138
# 17     108
# 38     103
# 19      98
#       ...
# 106      1
# 122      1
# 168      1
# 190      1
# 181      1
# Name: Total Expenses, Length: 156, dtype: int64

# %%
plt.hist(d8,bins='auto',label='Frequency',color='green')
plt.show()

# %%
d8 = df[(df['State']=='Oregon')]
d8
# Out:
#       Area Code   Date Market   Market Size            Product Product Line  \
# 156         503  40909   West  Small Market        Caffe Latte        Beans
# 157         503  40909   West  Small Market        Caffe Mocha        Beans
# 158         971  40909   West  Small Market     Decaf Espresso        Beans
# 159         971  40909   West  Small Market  Decaf Irish Cream        Beans
# 160         971  40909   West  Small Market          Chamomile       Leaves
# ...         ...    ...    ...           ...                ...          ...
# 4233        503  41609   West  Small Market        Caffe Mocha        Beans
# 4234        971  41609   West  Small Market     Decaf Espresso        Beans
# 4235        541  41609   West  Small Market           Amaretto        Beans
# 4236        541  41609   West  Small Market          Colombian        Beans
# 4237        541  41609   West  Small Market  Decaf Irish Cream        Beans
#
# ...

# %%
plt.hist(d8['Profit'],bins='auto',color='yellow',label='Profit')
plt.hist(d8['Budget Profit'],bins='auto',color='orange',label='Budget Profit')
plt.legend()
plt.title('frequency compare between profit and budget profit')
plt.xlabel('Profit')
plt.ylabel('Budget Profit')
plt.show()

# %%
df["Market"].value_counts()
# Out:
# West       1344
# Central    1344
# East        888
# South       672
# Name: Market, dtype: int64

# %%
d9=df[(df['Market']=='East')&(df['Product']=='Caffe Mocha')]
d9.shape
# Out:
# (120, 20)

# %%
plt.hist(d9['COGS'],bins='auto',color='green',label='COGS')
plt.hist(d9['Budget COGS'],bins='auto',color='lightblue',label='Budget COGS')
plt.legend()
plt.show()

# %%
df['Type'].value_counts()
# Out:
# Regular    2400
# Decaf      1848
# Name: Type, dtype: int64

# %%
d10=df[((df['Market']=='East') |(df['Market']=='Central')) & (df['Type']=='Decaf')]
d10.shape
# Out:
# (912, 20)

# %%
plt.hist(d10['Sales'],bins='auto',color='blue',label='Sales')
plt.hist(d10['Profit'],bins='auto',color='yellow',label='Profit')
plt.legend()
plt.show()

# %%
d11=df[df['Sales']>400]
print(d11.shape)
plt.boxplot(d11['COGS'])
plt.grid()
plt.show()
# Out:
# (418, 20)

# %%
df['Budget Profit'].value_counts()
# Out:
#  30     526
#  40     508
#  20     478
#  50     418
#  10     300
#        ...
# -230      2
# -320      2
# -130      2
#  520      2
#  460      2
# Name: Budget Profit, Length: 76, dtype: int64

# %%
d12=df[(df['Product']=='Decaf Espresso')]
d12
# Out:
#       Area Code   Date   Market   Market Size         Product Product Line  \
# 5           720  40909  Central  Major Market  Decaf Espresso        Beans
# 14          630  40909  Central  Major Market  Decaf Espresso        Beans
# 24          563  40909  Central  Small Market  Decaf Espresso        Beans
# 33          660  40909  Central  Small Market  Decaf Espresso        Beans
# 42          614  40909  Central  Major Market  Decaf Espresso        Beans
# ...         ...    ...      ...           ...             ...          ...
# 4200        435  41609     West  Small Market  Decaf Espresso        Beans
# 4212        209  41609     West  Major Market  Decaf Espresso        Beans
# 4224        775  41609     West  Small Market  Decaf Espresso        Beans
# 4234        971  41609     West  Small Market  Decaf Espresso        Beans
# 4245        360  41609     West  Small Market  Decaf Espresso        Beans
#
#      Product Type       State   Type  Budget COGS  Budget Margin  \
# ...

# %%
plt.boxplot(d12['Budget Profit'])
plt.grid()
plt.show()
